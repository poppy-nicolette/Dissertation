# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots()

# Example data
doc_types =  {"journal-article":14032745, "posted-content":1547055, "book-chapter":430661,
            "proceedings-article":223746,"edited-book":49406, "mongraph":47161, "report":28953,
            "other":24272, "book":23488, "report-component":11869, "reference-entry":11470,
            "book-part":1526, "book-section":1142, "reference-book":779, "report-series":189,
            "proceedings":4,
            "book-track":0, "book-series":0, "book-set":0,
            "component":0, "database":0,"dataset":0,
            "dissertation":0,"grant":0,
            "journal":0, "journal-issue":0, "journal-volume":0,
            "peer-review":0, "proceedings-series":0,
            "standard":0,   
            }


x_value = list(doc_types.keys())
y_value = list(doc_types.values())

bars = ax.barh(x_value, y_value, align='center', color='magenta')
ax.set_yticks(x_value, labels=x_value)

ax.set_xlim(0,18000000)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('Document types in Crossref')
ax.set_xlabel('Count of works in scientific format')
ax.set_title('Number of works from 2020-2025 with abstract')

# set values at end of bar
for i, bar in enumerate(bars):
    width = bar.get_width()
    ax.text(width, bar.get_y() + bar.get_height()/2, str(width), ha='left', va='center')


plt.show()

# %%
    Journal article types = 14032745, proceedings-article = 223746, book-section=1142, mongraph= 47161, report-component=11869, report= 28953, peer-review=0, book-track=0, book-part=1526, other= 24272, book= 23488, journal-volume=0, book-set=0, reference-entry= 11470, journal=0, component=0, book-chapter= 430661, proceedings-series=0, report-series= 189, proceedings=4,  database=0, standard=0, reference-book= 779,  posted-content= 1547055, journal-issue=0, dissertation=0, grant=0, dataset=0, book-series=0, edited-book=49406
