# %%
import bm25s_func as bm

bm.run_query()
# Out:
# 99
# Rank 1 (score: 0.78): URL: : https://doi.org/10.1177/1524839919827576 for title: Health Literacy Among Canadian Men Experiencing Prostate Cancer
# Rank 2 (score: 0.78): URL: : https://doi.org/10.1186/s12955-017-0716-7 for title: The relationship between health literacy and quality of life among frequent users of health care services: a cross-sectional study
# Rank 3 (score: 0.76): URL: : https://doi.org/10.1093/ckj/sfw076 for title: An observational study of health literacy and medication adherence in adult kidney transplant recipients

# %% [markdown]
# below is provided for times when the import is not working.

# %%
import sys
import os

# Add the directory containing bm25S_func.py to the Python path
module_path = os.path.abspath(os.path.join('/Users/poppyriddle/Documents/CODING_WORKING/Python/LIBRARIES/bm25S'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Now you can import the module
import bm25s_func

# Use the run_query function from the module
bm25s_func.run_query()
# Out:
# Rank 1 (score: 1.25): URL: : https://doi.org/10.1080/17408989.2021.2014438 for title: PLitPE: an intervention for physical literacy enriched pedagogy in Canadian elementary school physical education classes
# Rank 2 (score: 1.24): URL: : https://doi.org/10.1186/s12889-018-5897-4 for title: The relationship between physical literacy scores and adherence to Canadian physical activity and sedentary behaviour guidelines
# Rank 3 (score: 1.23): URL: : https://doi.org/10.1007/s11125-020-09519-5 for title: Increasing physical literacy in youth: A two-week Sport for Development program for children aged 6-10
