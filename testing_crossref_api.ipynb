# %% [markdown]
# # testing space for Crossref APIs modules
# - [x] test the Crossref_REST_API module
# - [ ] test the Crossref_XML_API module

# %%
from colorama import Fore, Back, Style
import sys
print(Fore.MAGENTA + f"{sys.path}")

# move this file to a more central and reusable location once working properly 
# and update the path
sys.path.append("/Users/poppyriddle/Documents/Github/Research_proposal")
from crossref_api import Crossref_REST_API
# Out:
# ['/Applications/Positron.app/Contents/Resources/app/extensions/positron-python/python_files/positron', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages']

# %%
a = Crossref_REST_API("10.1051/e3sconf/202448001017")
print(a)
print(f"title: {a.get_title()}")
print(f"doc_type: {a.get_type()}")
print(f"cited_by: {a.get_cited_by()}")
print(f"abstract: {a.get_abstract()[:100]}...")
print(f"URL: {a.get_url()}")
print(f"license: {a.get_license()}")
print(f"language: {a.get_language()}")
# Out:
# ...
# title: A comparison of current development system indicators for the oil-bearing layers under the abandonment of non-stationary water-flooding and hot water injection technologies
# doc_type: journal-article:None
# cited_by: 0
# abstract: <jats:p>In this work, based on the calculation of technological indicators, an assessment of the eff...
# URL: https://www.e3s-conferences.org/10.1051/e3sconf/202448001017
# license: ('vor', 'https://creativecommons.org/licenses/by/4.0/')
# language: None

# %%
help(Crossref_REST_API)

# %% [markdown]
# # now we test the XML API version
