# %% [markdown]
# # Chapter 3 Part 3:The case study
# author: <span style="color:magenta">Poppy Riddle</span><br>
# date: Mar 31, 2025
#
# ## purpose:
# - A discipline specific corpus as a sample of DOIs will be used. The BtS dataset is a good source for this as it is literature from which expert review, if needed, can be provided.
# - A source from Part 2 will guide decision on where to get metadata.
# - Characterization using methods from Part 1 will be applied to the metadata.
# - Characterizations will be mapped to configuration decisions for a RAG application.
# - Cohere Playground will be used to develop code to run in this notebook.
# - Explore tokenization options, explore retreivers, and explore how cited by can be used for ranking.
# - Chunking options for either BoW or embedding approach will be explored.
# - Explore BoW approach using TF-IDF, BM25, and sentence embedding approach using SciBERT.
# - Explore cited_by counts for reranking.
# - Expore results using precision, recall, and F1 scores. compare all configurations.
# - visualize results
#
# ## Data collection
# - original source of data: https://doi.org/10.5281/zenodo.14302591.
# - [ ] get DOIs, run through cleaning script found in jupyter Notebook DOI_errors.ipynb (may want to compress this down to one function except for manual inspection items. )
#     - [ ] Or just use v2 cleaned data here:/Users/poppyriddle/Documents/Github/BtS_data/dataset/v2/publications_v2.txt
# - [ ] send to OpenAlex REST API for works: select title,abstract,cited-by-count
# - [ ] clean title
# - [ ] reconstruct and clean abstract
#     - [ ] see reconstruct abstract code
#         - /Users/poppyriddle/Documents/PhD/Research_proposal/chapter3_part_2.ipynb
#         - /Users/poppyriddle/Documents/CODING_WORKING/Python/LIBRARIES/reconstruct_abstract
#
# # see notebooks in part_3_cohere venv folder.
